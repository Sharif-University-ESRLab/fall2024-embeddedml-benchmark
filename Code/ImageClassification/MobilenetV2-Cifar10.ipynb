# %%
import tensorflow as tf
import numpy as np
import tensorflow_datasets as tfds

def preprocess_data(image, label):
    image = tf.image.resize(image, (32, 32))
    image = tf.keras.applications.mobilenet_v2.preprocess_input(image)
    return image, tf.one_hot(label, depth=10)

data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.1),
    tf.keras.layers.RandomZoom(0.1),
])

(ds_train, ds_test), ds_info = tfds.load("cifar10", split=["train", "test"], as_supervised=True, with_info=True)

BATCH_SIZE = 64
AUTOTUNE = tf.data.experimental.AUTOTUNE

ds_train = ds_train.map(preprocess_data, num_parallel_calls=AUTOTUNE)
ds_train = ds_train.map(lambda x, y: (data_augmentation(x, training=True), y))
ds_train = ds_train.shuffle(5000).batch(BATCH_SIZE).prefetch(AUTOTUNE)

ds_test = ds_test.map(preprocess_data, num_parallel_calls=AUTOTUNE)
ds_test = ds_test.batch(BATCH_SIZE).prefetch(AUTOTUNE)

base_model = tf.keras.applications.MobileNetV2(input_shape=(32, 32, 3), include_top=False, weights="imagenet")

for layer in base_model.layers[-30:]:
    layer.trainable = True

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(10, activation="softmax")
])

initial_learning_rate = 0.0005
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate, decay_steps=1000, decay_rate=0.9)

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
              loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=["accuracy"])

EPOCHS = 20
model.fit(ds_train, validation_data=ds_test, epochs=EPOCHS)

model.save("cifar10_mobilenetv2_finetuned.h5")

converter = tf.lite.TFLiteConverter.from_keras_model(model)
converter.optimizations = [tf.lite.Optimize.DEFAULT]
tflite_model = converter.convert()

tflite_model_path = "cifar10_mobilenetv2_finetuned.tflite"
with open(tflite_model_path, "wb") as f:
    f.write(tflite_model)

print(f"TFLite model saved at {tflite_model_path}")
# Out:
# <ipython-input-2-11b72513c4e3>:28: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = tf.keras.applications.MobileNetV2(input_shape=(32, 32, 3), include_top=False, weights="imagenet")
# Epoch 1/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 154s 126ms/step - accuracy: 0.3120 - loss: 2.1227 - val_accuracy: 0.3536 - val_loss: 1.8329
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 87s 82ms/step - accuracy: 0.5842 - loss: 1.2263 - val_accuracy: 0.5744 - val_loss: 1.2202
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 69s 82ms/step - accuracy: 0.6484 - loss: 1.0383 - val_accuracy: 0.6881 - val_loss: 0.8862
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 72s 85ms/step - accuracy: 0.6879 - loss: 0.9166 - val_accuracy: 0.7106 - val_loss: 0.8280
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 81ms/step - accuracy: 0.7142 - loss: 0.8463 - val_accuracy: 0.7070 - val_loss: 0.9186
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 82ms/step - accuracy: 0.7294 - loss: 0.7945 - val_accuracy: 0.7181 - val_loss: 0.9574
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 70s 82ms/step - accuracy: 0.7426 - loss: 0.7521 - val_accuracy: 0.7565 - val_loss: 0.7709
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 64s 77ms/step - accuracy: 0.7600 - loss: 0.7097 - val_accuracy: 0.7470 - val_loss: 0.8237
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 84s 77ms/step - accuracy: 0.7698 - loss: 0.6796 - val_accuracy: 0.7843 - val_loss: 0.6850
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 77ms/step - accuracy: 0.7785 - loss: 0.6502 - val_accuracy: 0.7738 - val_loss: 0.6987
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 68s 80ms/step - accuracy: 0.7886 - loss: 0.6142 - val_accuracy: 0.7852 - val_loss: 0.6454
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 78s 78ms/step - accuracy: 0.7997 - loss: 0.5947 - val_accuracy: 0.7751 - val_loss: 0.6918
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 78ms/step - accuracy: 0.8055 - loss: 0.5662 - val_accuracy: 0.7826 - val_loss: 0.6618
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 80ms/step - accuracy: 0.8149 - loss: 0.5430 - val_accuracy: 0.8009 - val_loss: 0.6098
# Epoch 15/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 78ms/step - accuracy: 0.8222 - loss: 0.5221 - val_accuracy: 0.8009 - val_loss: 0.6007
# Epoch 16/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 77ms/step - accuracy: 0.8277 - loss: 0.4985 - val_accuracy: 0.8085 - val_loss: 0.5716
# Epoch 17/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 77ms/step - accuracy: 0.8388 - loss: 0.4741 - val_accuracy: 0.8107 - val_loss: 0.5500
# Epoch 18/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 65s 78ms/step - accuracy: 0.8411 - loss: 0.4622 - val_accuracy: 0.8225 - val_loss: 0.5289
# Epoch 19/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 67s 80ms/step - accuracy: 0.8471 - loss: 0.4467 - val_accuracy: 0.8237 - val_loss: 0.5379
# Epoch 20/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 66s 79ms/step - accuracy: 0.8527 - loss: 0.4346 - val_accuracy: 0.8287 - val_loss: 0.5140
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved artifact at '/tmp/tmp9c45jf82'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 32, 32, 3), dtype=tf.float32, name='keras_tensor_316')
# Output Type:
#   TensorSpec(shape=(None, 10), dtype=tf.float32, name=None)
# Captures:
#   136800184381328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184379984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184379216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184379600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184381136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184377872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184376720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184377104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184376912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184380752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184373264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184382096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184376528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184381904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184380560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184374800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184375568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184373072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184373840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184377680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184371920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184370000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184370768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184370192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184379024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184373456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184380944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184374032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184373648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136800184370960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797820359824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797820359440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797820359056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797820359248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797820360976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797820360592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817946768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817946192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797820358480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797820370768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817948304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817948688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817949072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817948880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817946384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817950224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817950608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817950992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817950800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817946960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817952144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817952528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817952912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817952720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817947920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817954064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817954448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817954832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817954640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817949840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817955984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817956368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817956752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817956560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817951760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817957904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817958288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817958672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817958480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817953680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817959824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817960208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817960592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817960400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817955600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817961744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817962320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817960976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817962128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797817959440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818306832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818308176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818308560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818308368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818307024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818309712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818310096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818310480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818310288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818307600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818311632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818312016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818312400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818312208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818307792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818313552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818313936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818314320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818314128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818309328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818315472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818315856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818316240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818316048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818311248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818317392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818317776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818318160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818317968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818313168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818319312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818319696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818320080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818319888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818315088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818321232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818321616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818322000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818321808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818317008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818320464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818897040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818896464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818322768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818318928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818898576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818898960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818899344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818899152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818896656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818900496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818900880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818901264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818901072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818897232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818902416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818902800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818903184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818902992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818898192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818904336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818904720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818905104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818904912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818900112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818906256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818906640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818907024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818906832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818902032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818908176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818908560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818908944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818908752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818903952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818910096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818910480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818910864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818910672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818905872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818912016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818912592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818911248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818912400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797818909712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819126032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819127376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819127760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819127568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819126992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819128912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819129296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819129680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819129488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819126224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819130832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819131216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819131600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819131408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819126416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819132752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819133136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819133520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819133328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819128528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819134672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819135056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819135440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819135248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819130448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819136592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819136976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819137360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819137168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819132368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819138512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819138896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819139280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819139088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819134288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819140432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819140816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819141200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819141008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819136208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819139664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816504592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816505360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819141968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797819138128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816506512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816506896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816507280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816507088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816505168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816508432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816508816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816509200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816509008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816504400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816510352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816510736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816511120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816510928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816506128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816512272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816512656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816513040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816512848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816508048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816514192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816514576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816514960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816514768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816509968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816516112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816516496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816516880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816516688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816511888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816518032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816518416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816518800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816518608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816513808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816519952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816520528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816519184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816520336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816517648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816881424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816882768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816883152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816882960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816881616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816884304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816884688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816885072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816884880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816882192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816886992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816887568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816886608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816885840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816888720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816889296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816889488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816888336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816885456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816889104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816891024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   136797816891600: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite model saved at cifar10_mobilenetv2_finetuned.tflite
